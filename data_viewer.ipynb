# %%
import pandas as pd

# %%
data=pd.read_csv("data/newevent_data.csv")
data.columns
# Out:
# Index(['id', 'title', 'location and city', 'start_datetime', 'end_datetime',
#        'mode', 'price', 'description', 'city', 'mode_clean', 'price_type',
#        'embed_text', 'url'],
#       dtype='object')

# %%
set(data['mode_clean'])
# Out:
# {'hybrid', 'in_person', 'online'}
